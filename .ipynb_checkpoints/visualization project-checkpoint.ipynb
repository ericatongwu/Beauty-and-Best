# %% [markdown]
# ## Project INF 551

# %% [markdown]
# Tong Wu       8593993026

# %%
import json
import seaborn as sns
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Input: file name
# Output: read into python
def read_json(file):
    with open(file) as f:
        data = json.load(f)
    return data

# %%
file  = "data.json"
data = read_json(file)

# %%
# Input: json in python
# Output: data in dictionary for plot
def get_data(json_loaded):

    user = {"time_len":[], "date":[], "name": []}

    for day in data:
        user["time_len"].append(day['time'])
        user["date"].append(day['date'])
        user["name"].append(day['type'])

    return user

# %%
time = np.array(user["time_len"])
date = np.array(user["date"])

# %%
data_df = pd.DataFrame.from_dict(data)

# %%
data_df['type_code'] = data_df.type.astype("category").cat.codes

# %%
data_df
# Out:
#           cloth        date  time         type  type_code
# 0      business  2019-01-14    94  super vocal          4
# 1         sport  2019-01-15    25        HIMYM          0
# 2   comfortable  2019-01-16    83  super vocal          4
# 3         dress  2019-01-17    45       office          2
# 4   comfortable  2019-01-18    93  super vocal          4
# 5         sport  2019-01-19    26        HIMYM          0
# 6         sport  2019-01-20    88  super vocal          4
# 7      business  2019-01-21    24        HIMYM          0
# 8         dress  2019-01-22    98  super vocal          4
# 9   comfortable  2019-01-23    20       office          2
# 10        dress  2019-01-24    94  super vocal          4
# 11  comfortable  2019-01-25    92  super vocal          4
# 12        sport  2019-01-26    10       office          2
# 13  comfortable  2019-01-27    40  super vocal          4
# 14        sport  2019-01-28    50        HIMYM          0
# ...

# %%
data_df.set_index('date',inplace=True)

#plot data
fig, ax = plt.subplots(figsize=(15,7))
data_df.plot(ax=ax)

#set ticks every week
ax.xaxis.set_major_locator(mdates.DayLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %%
data_df
# Out:
#                   cloth  time         type  type_code
# date
# 2019-01-14     business    94  super vocal          4
# 2019-01-15        sport    25        HIMYM          0
# 2019-01-16  comfortable    83  super vocal          4
# 2019-01-17        dress    45       office          2
# 2019-01-18  comfortable    93  super vocal          4
# 2019-01-19        sport    26        HIMYM          0
# 2019-01-20        sport    88  super vocal          4
# 2019-01-21     business    24        HIMYM          0
# 2019-01-22        dress    98  super vocal          4
# 2019-01-23  comfortable    20       office          2
# 2019-01-24        dress    94  super vocal          4
# 2019-01-25  comfortable    92  super vocal          4
# 2019-01-26        sport    10       office          2
# 2019-01-27  comfortable    40  super vocal          4
# 2019-01-28        sport    50        HIMYM          0
# 2019-01-29        dress   110  super vocal          4
# ...

# %%
data_df.plot(kind='bar',x='date',y='cloth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-73683b93da3b> in <module>()
#       1
# ----> 2 data_df.plot(kind='bar',x='date',y='cloth')
#       3 plt.show()
#
# /Applications/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# ...
